# %% [markdown]
# # Imports

# %%
import sys 
import os
sys.path.append(os.path.join(os.getcwd(), '../Code/'))
from Dataset import *

# %%
import tensorflow as tf

# %%
from keras.models import Sequential

from keras.layers.convolutional import Conv2D
# Out:
# Using TensorFlow backend.

# %%
from PIL import Image

# %% [markdown]
# # Load data

# %%
# Load dataset
training = Dataset('../Data/NYU_Silberman_100.mat')
testing = Dataset('../Data/NYU_Silberman_101_120.mat')

# %% [markdown]
# # Loss function

# %%
def mean_dot_product(y_true, y_pred):
    dot = tf.einsum('ijkl,ijkl->ijk',tf.nn.l2_normalize(y_true,3),tf.nn.l2_normalize(y_pred,3))
    n = tf.cast(tf.count_nonzero(dot),tf.float32)
    mean = tf.reduce_sum(dot) / n
    return -1 * mean

# %%
norms[1,23,50,0]
# Out:
# -0.87151724

# %%
x = norms
y = np.copy(x)
y[1,23,50,0] = -0.87
tfx = tf.constant(x)
tfy = tf.constant(y)

# %%
loss = mean_dot_product(tfx,tfy)

sess = tf.Session()
np.array(sess.run(loss))

# %% [markdown]
# # Baseline Model

# %%
def baseline_model():
    # create model
    model = Sequential()
    model.add(Conv2D(12, (5, 5), input_shape=(240, 320, 3), activation='relu', padding='same'))
    model.add(Conv2D(32, (5, 5), activation='relu', padding='same'))
    model.add(Conv2D(12, (5, 5), activation='relu', padding='same'))
    model.add(Conv2D(3, (5, 5), activation='relu', padding='same'))
    # Compile model
    model.compile(loss= mean_dot_product, optimizer='sgd')
    return model

# %% [markdown]
# # Training

# %%
model = baseline_model()

# %%
for epoch in range(1):
    print('My Epoch', epoch)
    imgs , norms , masks = training.get_batch(1000, 320, 240)
    x = imgs
    y = np.multiply(masks,norms)
    model.fit(x, y, batch_size=10, epochs=2)
# Out:
# My Epoch 0
# Epoch 1/2
# 1000/1000 [==============================] - 9s - loss: 0.4124
# Epoch 2/2
# 1000/1000 [==============================] - 9s - loss: 0.4124

# %%
from keras.models import load_model

# %%
model = load_model('../Data/BaselineV1.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d1e8ac52c360> in <module>()
# ----> 1 model = load_model('../Data/BaselineV1.h5')
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/models.py in load_model(filepath, custom_objects, compile)
#     262                       metrics=metrics,
#     263                       loss_weights=loss_weights,
# --> 264                       sample_weight_mode=sample_weight_mode)
#     265
#     266         # Set optimizer weights.
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/models.py in compile(self, optimizer, loss, metrics, sample_weight_mode, **kwargs)
#     779                            metrics=metrics,
#     780                            sample_weight_mode=sample_weight_mode,
# --> 781                            **kwargs)
#     782         self.optimizer = self.model.optimizer
#     783         self.loss = self.model.loss
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, **kwargs)
#     679             loss_functions = [losses.get(l) for l in loss]
#     680         else:
# --> 681             loss_function = losses.get(loss)
#     682             loss_functions = [loss_function for _ in range(len(self.outputs))]
#     683         self.loss_functions = loss_functions
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/losses.py in get(identifier)
#     100     if isinstance(identifier, six.string_types):
#     101         identifier = str(identifier)
# --> 102         return deserialize(identifier)
#     103     elif callable(identifier):
#     104         return identifier
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/losses.py in deserialize(name, custom_objects)
#      92                                     module_objects=globals(),
#      93                                     custom_objects=custom_objects,
# ---> 94                                     printable_module_name='loss function')
#      95
#      96
#
# /usr/not-backed-up/anaconda/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     157             if fn is None:
#     158                 raise ValueError('Unknown ' + printable_module_name +
# --> 159                                  ':' + function_name)
#     160         return fn
#     161     else:
#
# ValueError: Unknown loss function:mean_dot_product

# %% [markdown]
# # Prediction

# %%
imgs , norms , masks = testing.get_batch(10, 320, 240)

# %%
pred = model.predict(norms,batch_size=1)

# %%
i = 1

# %%
Image.fromarray(imgs[i,:,:,:].astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7F5F445E9A90>

# %%
Image.fromarray((np.abs(pred[i,:,:,:])*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7F5F445E9EF0>

# %%
Image.fromarray((np.abs(norms[i,:,:,:])*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7F5F445E9D30>

# %%
Image.fromarray(masks[i,:,:,:].reshape(240,320)*255)
# Out:
# <PIL.Image.Image image mode=L size=320x240 at 0x7FBBA29B3B70>

# %%
model.save('../Data/BaselineV1.h5')
